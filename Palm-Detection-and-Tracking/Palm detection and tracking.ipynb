# %%
# !pip install opencv-python==3.4.5.20

# %%
import cv2
import numpy as np

hand_hist = None
traverse_point = []
total_rectangle = 9
hand_rect_one_x = None
hand_rect_one_y = None

hand_rect_two_x = None
hand_rect_two_y = None


def rescale_frame(frame, wpercent=130, hpercent=130):
    width = int(frame.shape[1] * wpercent / 100)
    height = int(frame.shape[0] * hpercent / 100)
    return cv2.resize(frame, (width, height), interpolation=cv2.INTER_AREA)


def contours(hist_mask_image):
    gray_hist_mask_image = cv2.cvtColor(hist_mask_image, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(gray_hist_mask_image, 0, 255, 0)
    #print(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    cont, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    return cont

def draw_rect(frame):
    rows, cols, _ = frame.shape
    global total_rectangle, hand_rect_one_x, hand_rect_one_y, hand_rect_two_x, hand_rect_two_y

    hand_rect_one_x = np.array(
        [6 * rows / 20, 6 * rows / 20, 6 * rows / 20, 9 * rows / 20, 9 * rows / 20, 9 * rows / 20, 12 * rows / 20,
         12 * rows / 20, 12 * rows / 20], dtype=np.uint32)

    hand_rect_one_y = np.array(
        [9 * cols / 20, 10 * cols / 20, 11 * cols / 20, 9 * cols / 20, 10 * cols / 20, 11 * cols / 20, 9 * cols / 20,
         10 * cols / 20, 11 * cols / 20], dtype=np.uint32)

    hand_rect_two_x = hand_rect_one_x + 10
    hand_rect_two_y = hand_rect_one_y + 10

    for i in range(total_rectangle):
        cv2.rectangle(frame, (hand_rect_one_y[i], hand_rect_one_x[i]),
                      (hand_rect_two_y[i], hand_rect_two_x[i]),
                      (0, 255, 0), 1)

    return frame


def hand_histogram(frame):
    global hand_rect_one_x, hand_rect_one_y

    hsv_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    roi = np.zeros([90, 10, 3], dtype=hsv_frame.dtype)

    for i in range(total_rectangle):
        roi[i * 10: i * 10 + 10, 0: 10] = hsv_frame[hand_rect_one_x[i]:hand_rect_one_x[i] + 10,
                                          hand_rect_one_y[i]:hand_rect_one_y[i] + 10]

    hand_hist = cv2.calcHist([roi], [0, 1], None, [180, 256], [0, 180, 0, 256])
    return cv2.normalize(hand_hist, hand_hist, 0, 255, cv2.NORM_MINMAX)


def hist_masking(frame, hist):
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    dst = cv2.calcBackProject([hsv], [0, 1], hist, [0, 180, 0, 256], 1)

    disc = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (31, 31))
    cv2.filter2D(dst, -1, disc, dst)

    ret, thresh = cv2.threshold(dst, 150, 255, cv2.THRESH_BINARY)

    # thresh = cv2.dilate(thresh, None, iterations=5)

    thresh = cv2.merge((thresh, thresh, thresh))

    return cv2.bitwise_and(frame, thresh)


def centroid(max_contour):
    moment = cv2.moments(max_contour)
    if moment['m00'] != 0:
        cx = int(moment['m10'] / moment['m00'])
        cy = int(moment['m01'] / moment['m00'])
        return cx, cy
    else:
        return None


def farthest_point(defects, contour, centroid):
    if defects is not None and centroid is not None:
        s = defects[:, 0][:, 0]
        cx, cy = centroid

        x = np.array(contour[s][:, 0][:, 0], dtype=np.float)
        y = np.array(contour[s][:, 0][:, 1], dtype=np.float)

        xp = cv2.pow(cv2.subtract(x, cx), 2)
        yp = cv2.pow(cv2.subtract(y, cy), 2)
        dist = cv2.sqrt(cv2.add(xp, yp))

        dist_max_i = np.argmax(dist)

        if dist_max_i < len(s):
            farthest_defect = s[dist_max_i]
            farthest_point = tuple(contour[farthest_defect][0])
            return farthest_point
        else:
            return None


def draw_circles(frame, traverse_point):
    if traverse_point is not None:
        for i in range(len(traverse_point)):
            cv2.circle(frame, traverse_point[i], int(5 - (5 * i * 3) / 100), [0, 255, 255], -1)


def manage_image_opr(frame, hand_hist):
    hist_mask_image = hist_masking(frame, hand_hist)

    hist_mask_image = cv2.erode(hist_mask_image, None, iterations=2)
    hist_mask_image = cv2.dilate(hist_mask_image, None, iterations=2)

    contour_list = contours(hist_mask_image)
    max_cont = max(contour_list, key=cv2.contourArea)

    cnt_centroid = centroid(max_cont)
    cv2.circle(frame, cnt_centroid, 5, [255, 0, 255], -1)

    if max_cont is not None:
        hull = cv2.convexHull(max_cont, returnPoints=False)
        defects = cv2.convexityDefects(max_cont, hull)
        far_point = farthest_point(defects, max_cont, cnt_centroid)
        print("Centroid : " + str(cnt_centroid) + ", farthest Point : " + str(far_point))
        cv2.circle(frame, far_point, 5, [0, 0, 255], -1)
        if len(traverse_point) < 20:
            traverse_point.append(far_point)
        else:
            traverse_point.pop(0)
            traverse_point.append(far_point)

        draw_circles(frame, traverse_point)


def main():
    global hand_hist
    is_hand_hist_created = False
    capture = cv2.VideoCapture(0)

    while capture.isOpened():
        pressed_key = cv2.waitKey(1)
        _, frame = capture.read()
        frame = cv2.flip(frame, 1)

        if pressed_key & 0xFF == ord('z'):
            is_hand_hist_created = True
            hand_hist = hand_histogram(frame)

        if is_hand_hist_created:
            manage_image_opr(frame, hand_hist)

        else:
            frame = draw_rect(frame)

        cv2.imshow("Live Feed", rescale_frame(frame))

        if pressed_key == 27:
            break

    cv2.destroyAllWindows()
    capture.release()


if __name__ == '__main__':
    main()
# Out:
# Centroid : (340, 258), farthest Point : (317, 60)
# Centroid : (341, 257), farthest Point : (310, 60)
# Centroid : (339, 256), farthest Point : (310, 60)
# Centroid : (339, 257), farthest Point : (306, 60)
# Centroid : (339, 256), farthest Point : (320, 60)
# Centroid : (339, 256), farthest Point : (306, 60)
# Centroid : (334, 257), farthest Point : (302, 60)
# Centroid : (324, 262), farthest Point : (301, 60)
# Centroid : (313, 277), farthest Point : (303, 85)
# Centroid : (302, 296), farthest Point : (293, 133)
# Centroid : (293, 321), farthest Point : (290, 183)
# Centroid : (293, 335), farthest Point : (380, 419)
# Centroid : (283, 337), farthest Point : (376, 407)
# Centroid : (276, 331), farthest Point : (373, 419)
# Centroid : (283, 325), farthest Point : (265, 191)
# Centroid : (292, 319), farthest Point : (283, 185)
# Centroid : (296, 311), farthest Point : (284, 172)
# Centroid : (305, 311), farthest Point : (293, 170)
# Centroid : (309, 318), farthest Point : (305, 185)
# Centroid : (303, 325), farthest Point : (302, 198)
# Centroid : (298, 330), farthest Point : (301, 211)
# Centroid : (301, 331), farthest Point : (301, 208)
# Centroid : (305, 328), farthest Point : (326, 208)
# Centroid : (305, 325), farthest Point : (310, 200)
# Centroid : (305, 325), farthest Point : (310, 200)
# Centroid : (309, 321), farthest Point : (307, 192)
# Centroid : (329, 315), farthest Point : (328, 179)
# Centroid : (341, 316), farthest Point : (344, 180)
# Centroid : (355, 320), farthest Point : (378, 184)
# Centroid : (359, 324), farthest Point : (387, 195)
# Centroid : (356, 328), farthest Point : (373, 204)
# Centroid : (352, 330), farthest Point : (364, 208)
# Centroid : (344, 330), farthest Point : (365, 207)
# Centroid : (335, 328), farthest Point : (335, 204)
# Centroid : (328, 326), farthest Point : (332, 199)
# Centroid : (321, 322), farthest Point : (320, 191)
# Centroid : (310, 318), farthest Point : (303, 181)
# Centroid : (302, 312), farthest Point : (285, 171)
# Centroid : (302, 304), farthest Point : (279, 158)
# Centroid : (309, 296), farthest Point : (288, 142)
# Centroid : (325, 289), farthest Point : (302, 129)
# Centroid : (349, 285), farthest Point : (336, 127)
# Centroid : (370, 283), farthest Point : (361, 118)
# Centroid : (388, 284), farthest Point : (388, 124)
# Centroid : (406, 288), farthest Point : (427, 130)
# Centroid : (419, 295), farthest Point : (434, 143)
# Centroid : (428, 302), farthest Point : (461, 162)
# Centroid : (438, 306), farthest Point : (489, 176)
# Centroid : (438, 309), farthest Point : (480, 180)
# Centroid : (437, 308), farthest Point : (482, 177)
# Centroid : (432, 301), farthest Point : (472, 160)
# Centroid : (419, 297), farthest Point : (458, 149)
# Centroid : (401, 291), farthest Point : (418, 134)
# Centroid : (386, 287), farthest Point : (394, 132)
# Centroid : (367, 285), farthest Point : (374, 129)
# Centroid : (348, 284), farthest Point : (363, 135)
# Centroid : (332, 283), farthest Point : (323, 121)
# Centroid : (317, 287), farthest Point : (299, 124)
# Centroid : (307, 297), farthest Point : (293, 146)
# Centroid : (304, 307), farthest Point : (268, 170)
# Centroid : (309, 317), farthest Point : (288, 182)
# Centroid : (319, 325), farthest Point : (302, 198)
# Centroid : (332, 330), farthest Point : (412, 419)
# Centroid : (347, 333), farthest Point : (348, 220)
# Centroid : (363, 334), farthest Point : (356, 218)
# Centroid : (378, 332), farthest Point : (380, 211)
# Centroid : (392, 328), farthest Point : (395, 211)
# Centroid : (404, 323), farthest Point : (424, 203)
# Centroid : (413, 317), farthest Point : (423, 191)
# Centroid : (418, 305), farthest Point : (426, 174)
# Centroid : (418, 296), farthest Point : (441, 157)
# Centroid : (412, 286), farthest Point : (431, 142)
# Centroid : (402, 279), farthest Point : (406, 127)
# Centroid : (389, 274), farthest Point : (392, 117)
# Centroid : (372, 274), farthest Point : (368, 110)
# Centroid : (354, 277), farthest Point : (352, 119)
# Centroid : (337, 283), farthest Point : (329, 123)
# Centroid : (328, 290), farthest Point : (317, 139)
# Centroid : (324, 299), farthest Point : (314, 156)
# Centroid : (327, 309), farthest Point : (311, 170)
# Centroid : (337, 320), farthest Point : (306, 200)
# Centroid : (349, 326), farthest Point : (344, 205)
# Centroid : (364, 332), farthest Point : (364, 214)
# Centroid : (380, 335), farthest Point : (382, 228)
# Centroid : (394, 335), farthest Point : (421, 232)
# Centroid : (406, 334), farthest Point : (434, 232)
# Centroid : (426, 319), farthest Point : (448, 206)
# Centroid : (434, 314), farthest Point : (367, 419)
# Centroid : (442, 309), farthest Point : (377, 419)
# Centroid : (442, 309), farthest Point : (377, 419)
# Centroid : (456, 299), farthest Point : (456, 166)
# Centroid : (462, 286), farthest Point : (485, 404)
# Centroid : (456, 316), farthest Point : (530, 222)
# Centroid : (454, 319), farthest Point : (531, 224)
# Centroid : (455, 300), farthest Point : (460, 179)
# Centroid : (448, 305), farthest Point : (504, 198)
# Centroid : (436, 313), farthest Point : (365, 419)
# Centroid : (425, 316), farthest Point : (352, 417)
# Centroid : (412, 314), farthest Point : (451, 195)
# Centroid : (400, 309), farthest Point : (430, 179)
# Centroid : (387, 305), farthest Point : (417, 176)
# Centroid : (375, 300), farthest Point : (391, 165)
# Centroid : (363, 294), farthest Point : (365, 151)
# Centroid : (351, 293), farthest Point : (352, 147)
# Centroid : (339, 291), farthest Point : (336, 142)
# Centroid : (326, 292), farthest Point : (323, 144)
# Centroid : (314, 292), farthest Point : (303, 144)
# Centroid : (304, 296), farthest Point : (291, 150)
# Centroid : (292, 298), farthest Point : (273, 150)
# Centroid : (291, 301), farthest Point : (259, 158)
# Centroid : (300, 299), farthest Point : (275, 156)
# Centroid : (314, 298), farthest Point : (299, 158)
# Centroid : (328, 295), farthest Point : (308, 150)
# Centroid : (343, 294), farthest Point : (325, 146)
# Centroid : (354, 293), farthest Point : (344, 145)
# Centroid : (360, 292), farthest Point : (357, 145)
# Centroid : (358, 291), farthest Point : (359, 143)
# Centroid : (347, 291), farthest Point : (345, 141)
# Centroid : (333, 290), farthest Point : (334, 140)
# Centroid : (318, 290), farthest Point : (313, 139)
# Centroid : (305, 291), farthest Point : (294, 138)
# Centroid : (298, 292), farthest Point : (279, 140)
# Centroid : (302, 295), farthest Point : (285, 148)
# Centroid : (314, 298), farthest Point : (293, 152)
# Centroid : (331, 298), farthest Point : (315, 155)
# Centroid : (353, 301), farthest Point : (342, 162)
# Centroid : (372, 302), farthest Point : (371, 160)
# Centroid : (384, 302), farthest Point : (404, 162)
# Centroid : (388, 303), farthest Point : (401, 163)
# Centroid : (384, 300), farthest Point : (408, 160)
# Centroid : (375, 296), farthest Point : (399, 153)
# Centroid : (365, 291), farthest Point : (383, 147)
# Centroid : (350, 290), farthest Point : (354, 137)
# Centroid : (336, 291), farthest Point : (334, 140)
# Centroid : (327, 294), farthest Point : (313, 150)
# Centroid : (324, 295), farthest Point : (310, 150)
# Centroid : (325, 301), farthest Point : (311, 159)
# Centroid : (331, 307), farthest Point : (319, 171)
# Centroid : (342, 308), farthest Point : (334, 172)
# Centroid : (356, 307), farthest Point : (349, 174)
# Centroid : (370, 304), farthest Point : (367, 169)
# Centroid : (376, 297), farthest Point : (375, 157)
# Centroid : (370, 291), farthest Point : (396, 151)
# Centroid : (353, 285), farthest Point : (363, 131)
# Centroid : (331, 280), farthest Point : (335, 123)
# Centroid : (310, 273), farthest Point : (302, 108)
# Centroid : (289, 270), farthest Point : (275, 99)
# Centroid : (272, 272), farthest Point : (247, 103)
# Centroid : (263, 274), farthest Point : (230, 109)
# Centroid : (261, 277), farthest Point : (228, 111)
# Centroid : (268, 290), farthest Point : (238, 132)
# Centroid : (277, 303), farthest Point : (243, 153)
# Centroid : (297, 312), farthest Point : (279, 180)
# Centroid : (297, 312), farthest Point : (279, 180)
# Centroid : (342, 325), farthest Point : (339, 208)
# Centroid : (361, 324), farthest Point : (361, 205)
# Centroid : (377, 321), farthest Point : (383, 200)
# Centroid : (390, 314), farthest Point : (402, 187)
# Centroid : (401, 306), farthest Point : (337, 419)
# Centroid : (411, 300), farthest Point : (420, 166)
# Centroid : (419, 297), farthest Point : (452, 159)
# Centroid : (426, 296), farthest Point : (357, 419)
# Centroid : (429, 301), farthest Point : (358, 419)
# Centroid : (429, 306), farthest Point : (352, 419)
# Centroid : (428, 313), farthest Point : (470, 191)
# Centroid : (421, 323), farthest Point : (465, 213)
# Centroid : (410, 331), farthest Point : (457, 227)
# Centroid : (396, 331), farthest Point : (441, 224)
# Centroid : (382, 328), farthest Point : (422, 221)
# Centroid : (369, 318), farthest Point : (401, 198)
# Centroid : (358, 311), farthest Point : (390, 183)
# Centroid : (347, 303), farthest Point : (366, 167)
# Centroid : (340, 297), farthest Point : (340, 155)
# Centroid : (336, 297), farthest Point : (343, 156)
# Centroid : (334, 302), farthest Point : (333, 161)
# Centroid : (339, 307), farthest Point : (337, 172)
# Centroid : (347, 313), farthest Point : (349, 183)
# Centroid : (356, 318), farthest Point : (372, 195)
# Centroid : (369, 318), farthest Point : (386, 197)
# Centroid : (379, 314), farthest Point : (406, 192)
# Centroid : (384, 305), farthest Point : (407, 175)
# Centroid : (389, 297), farthest Point : (398, 163)
# Centroid : (396, 293), farthest Point : (406, 156)
# Centroid : (401, 293), farthest Point : (412, 150)
# Centroid : (402, 299), farthest Point : (421, 161)
# Centroid : (399, 307), farthest Point : (433, 180)
# Centroid : (389, 313), farthest Point : (425, 190)
# Centroid : (376, 320), farthest Point : (410, 204)
# Centroid : (362, 321), farthest Point : (378, 200)
# Centroid : (350, 318), farthest Point : (377, 198)
# Centroid : (340, 309), farthest Point : (343, 178)
# Centroid : (334, 300), farthest Point : (332, 161)
# Centroid : (337, 289), farthest Point : (334, 144)
# Centroid : (348, 287), farthest Point : (335, 137)
# Centroid : (361, 291), farthest Point : (363, 144)
# Centroid : (369, 299), farthest Point : (376, 159)
# Centroid : (371, 309), farthest Point : (380, 178)
# Centroid : (362, 320), farthest Point : (390, 197)
# Centroid : (350, 322), farthest Point : (377, 204)
# Centroid : (340, 317), farthest Point : (340, 199)
# Centroid : (334, 308), farthest Point : (334, 177)
# Centroid : (333, 298), farthest Point : (324, 161)
# Centroid : (333, 289), farthest Point : (322, 142)
# Centroid : (334, 282), farthest Point : (324, 135)
# Centroid : (326, 282), farthest Point : (319, 130)
# Centroid : (309, 287), farthest Point : (294, 137)
# Centroid : (301, 293), farthest Point : (278, 142)
# Centroid : (305, 301), farthest Point : (287, 161)
# Centroid : (316, 309), farthest Point : (302, 176)
# Centroid : (329, 314), farthest Point : (322, 188)
# Centroid : (342, 313), farthest Point : (344, 192)
# Centroid : (351, 309), farthest Point : (346, 180)
# Centroid : (355, 302), farthest Point : (360, 167)
# Centroid : (357, 296), farthest Point : (353, 160)
# Centroid : (355, 296), farthest Point : (350, 154)
# Centroid : (357, 299), farthest Point : (356, 158)
# Centroid : (357, 301), farthest Point : (379, 169)
# Centroid : (357, 301), farthest Point : (379, 169)
# Centroid : (356, 302), farthest Point : (356, 163)
# Centroid : (355, 300), farthest Point : (355, 161)
# Centroid : (355, 301), farthest Point : (355, 168)
# Centroid : (354, 300), farthest Point : (361, 159)
# Centroid : (352, 300), farthest Point : (354, 157)
# Centroid : (351, 301), farthest Point : (351, 161)
