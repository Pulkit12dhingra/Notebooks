# %%
try:
  # %tensorflow_version 2.x  # Colab only.
except Exception:
  pass

import tensorflow as tf
print(tf.__version__)
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `2.x  # Colab only.`. This will be interpreted as: `2.x`.
#
#
# TensorFlow 2.x selected.
# 2.3.0

# %%
# More imports
from tensorflow.keras.layers import Input, LSTM, GRU, SimpleRNN, Dense, GlobalMaxPool1D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
securities=pd.read_csv("securities.csv")
fundamentals=pd.read_csv("fundamentals.csv")
prices=pd.read_csv("prices.csv")
prices_split=pd.read_csv("prices-split-adjusted.csv")

# %%
securities.head()
#securities.columns
# Out:
#   Ticker symbol             Security  ... Date first added      CIK
# 0           MMM           3M Company  ...              NaN    66740
# 1           ABT  Abbott Laboratories  ...       1964-03-31     1800
# 2          ABBV               AbbVie  ...       2012-12-31  1551152
# 3           ACN        Accenture plc  ...       2011-07-06  1467373
# 4          ATVI  Activision Blizzard  ...       2015-08-31   718877
#
# [5 rows x 8 columns]

# %%
fundamentals.head()
#fundamentals.columns
# Out:
#    Unnamed: 0 Ticker Symbol  ... Earnings Per Share  Estimated Shares Outstanding
# 0           0           AAL  ...              -5.60                  3.350000e+08
# 1           1           AAL  ...             -11.25                  1.630222e+08
# 2           2           AAL  ...               4.02                  7.169154e+08
# 3           3           AAL  ...              11.39                  6.681299e+08
# 4           4           AAP  ...               5.29                  7.328355e+07
#
# [5 rows x 79 columns]

# %%
prices.head()
# Out:
#                   date symbol        open  ...         low        high     volume
# 0  2016-01-05 00:00:00   WLTW  123.430000  ...  122.309998  126.250000  2163600.0
# 1  2016-01-06 00:00:00   WLTW  125.239998  ...  119.940002  125.540001  2386400.0
# 2  2016-01-07 00:00:00   WLTW  116.379997  ...  114.930000  119.739998  2489500.0
# 3  2016-01-08 00:00:00   WLTW  115.480003  ...  113.500000  117.440002  2006300.0
# 4  2016-01-11 00:00:00   WLTW  117.010002  ...  114.089996  117.330002  1408600.0
#
# [5 rows x 7 columns]

# %%
prices_split.head()
# Out:
#          date symbol        open       close         low        high     volume
# 0  2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000  2163600.0
# 1  2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001  2386400.0
# 2  2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998  2489500.0
# 3  2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002  2006300.0
# 4  2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002  1408600.0

# %%
prices_split.tail()
# Out:
#               date symbol       open  ...        low       high     volume
# 593045  2014-12-09    VFC  72.680000  ...  72.000000  73.410004  1574000.0
# 593046  2014-12-09   VIAB  74.279999  ...  73.510002  74.760002  2375400.0
# 593047  2014-12-09    VLO  47.959999  ...  46.939999  48.680000  9498100.0
# 593048  2014-12-09    VMC  64.540001  ...  64.400002  66.050003   723400.0
# 593049   2014-12-0    NaN        NaN  ...        NaN        NaN        NaN
#
# [5 rows x 7 columns]

# %%
l=list(prices_split['symbol'])

# %%
company_name=input("Enter the symbol of the company whose prices you want to predict")
if company_name in l:
  pass
else:
  print("Please Recheck the symbol enttered, the symbol doensot exist in the database")
# Out:
# Enter the symbol of the company whose prices you want to predictWLTW

# %%
s=prices_split.groupby('symbol')

# %%
s.head()
# Out:
#               date symbol        open  ...         low        high     volume
# 0       2016-01-05   WLTW  123.430000  ...  122.309998  126.250000  2163600.0
# 1       2016-01-06   WLTW  125.239998  ...  119.940002  125.540001  2386400.0
# 2       2016-01-07   WLTW  116.379997  ...  114.930000  119.739998  2489500.0
# 3       2016-01-08   WLTW  115.480003  ...  113.500000  117.440002  2006300.0
# 4       2016-01-11   WLTW  117.010002  ...  114.089996  117.330002  1408600.0
# ...            ...    ...         ...  ...         ...         ...        ...
# 462770  2013-11-19   ALLE   48.990002  ...   45.299999   49.000000  1682000.0
# 463260  2013-11-20   ALLE   45.980000  ...   43.990002   46.000000  1106900.0
# 463750  2013-11-21   ALLE   44.500000  ...   43.040001   45.150002   730200.0
# 464240  2013-11-22   ALLE   43.900002  ...   43.250000   44.099998   947600.0
# 593049   2014-12-0    NaN         NaN  ...         NaN         NaN        NaN
#
# [2456 rows x 7 columns]

# %%
df=s.get_group(company_name)

# %%
df.head()
# Out:
#          date symbol        open       close         low        high     volume
# 0  2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000  2163600.0
# 1  2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001  2386400.0
# 2  2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998  2489500.0
# 3  2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002  2006300.0
# 4  2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002  1408600.0

# %%
df.tail()
# Out:
#            date symbol        open  ...         low        high    volume
# 246  2016-12-23   WLTW  123.089996  ...  122.709999  124.660004  361900.0
# 247  2016-12-27   WLTW  124.570000  ...  124.010002  124.900002  382900.0
# 248  2016-12-28   WLTW  124.300003  ...  121.900002  124.300003  429900.0
# 249  2016-12-29   WLTW  122.449997  ...  121.599998  123.070000  216600.0
# 250  2016-12-30   WLTW  122.589996  ...  121.389999  123.559998  466400.0
#
# [5 rows x 7 columns]

# %%
# calculate returns by first shifting the data
df['PrevClose'] = df['close'].shift(1) # move everything up 1

# so now it's like
# close / prev close
# x[2] x[1]
# x[3] x[2]
# x[4] x[3]
# ...
# x[t] x[t-1]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.head()
# Out:
#          date symbol        open  ...        high     volume   PrevClose
# 0  2016-01-05   WLTW  123.430000  ...  126.250000  2163600.0         NaN
# 1  2016-01-06   WLTW  125.239998  ...  125.540001  2386400.0  125.839996
# 2  2016-01-07   WLTW  116.379997  ...  119.739998  2489500.0  119.980003
# 3  2016-01-08   WLTW  115.480003  ...  117.440002  2006300.0  114.949997
# 4  2016-01-11   WLTW  117.010002  ...  117.330002  1408600.0  116.620003
#
# [5 rows x 8 columns]

# %%
# then the return is
# (x[t] - x[t-1]) / x[t-1]
df['Return'] = (df['close'] - df['PrevClose']) / df['PrevClose']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.head()
# Out:
#          date symbol        open  ...     volume   PrevClose    Return
# 0  2016-01-05   WLTW  123.430000  ...  2163600.0         NaN       NaN
# 1  2016-01-06   WLTW  125.239998  ...  2386400.0  125.839996 -0.046567
# 2  2016-01-07   WLTW  116.379997  ...  2489500.0  119.980003 -0.041924
# 3  2016-01-08   WLTW  115.480003  ...  2006300.0  114.949997  0.014528
# 4  2016-01-11   WLTW  117.010002  ...  1408600.0  116.620003 -0.014149
#
# [5 rows x 9 columns]

# %%
# Now let's try an LSTM to predict returns
df['Return'].hist()

# %%
series = df['Return'].values[1:].reshape(-1, 1)

# Normalize the data
# Note: I didn't think about where the true boundary is, this is just approx.
scaler = StandardScaler()
scaler.fit(series[:len(series) // 2])
series = scaler.transform(series).flatten()

# %%
### build the dataset
# let's see if we can use T past values to predict the next value
T = 10
D = 1
X = []
Y = []
for t in range(len(series) - T):
  x = series[t:t+T]
  X.append(x)
  y = series[t+T]
  Y.append(y)

X = np.array(X).reshape(-1, T, 1) # Now the data should be N x T x D
Y = np.array(Y)
N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (240, 10, 1) Y.shape (240,)

# %%
### try autoregressive RNN model
i = Input(shape=(T, 1))
x = LSTM(5)(i)
#x = Dense(500)(x)
#x = Dense(200)(x)
x = Dense(50)(x)
#x = Dense(20)(x)
x = Dense(1)(x)
model = Model(i, x)
model.compile(
  loss='mse',
  optimizer=Adam(lr=0.01),
)

# train the RNN
r = model.fit(
  X[:-N//2], Y[:-N//2],
  epochs=200,
  validation_data=(X[-N//2:], Y[-N//2:]),
)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 110ms/step - loss: 0.8831 - val_loss: 0.5210
# Epoch 2/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8764 - val_loss: 0.5106
# Epoch 3/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.8627 - val_loss: 0.5152
# Epoch 4/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.8558 - val_loss: 0.5099
# Epoch 5/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.8542 - val_loss: 0.5009
# Epoch 6/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.8483 - val_loss: 0.5049
# Epoch 7/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.8424 - val_loss: 0.5144
# Epoch 8/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.8346 - val_loss: 0.5304
# Epoch 9/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.8326 - val_loss: 0.5191
# Epoch 10/200
# ...

# %%
# Plot loss per iteration
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# One-step forecast using true targets
outputs = model.predict(X)
print(outputs.shape)
predictions = outputs[:,0]

plt.plot(Y, label='targets')
plt.plot(predictions, label='predictions')
plt.legend()
plt.show()
# Out:
# (240, 1)
